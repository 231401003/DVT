# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HDC0422037\Desktop\Churn_Modelling.csv")

print(df)
# Out:
#     RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602   Hargrave          619    France  Female   42
# 1           2    15647311       Hill          608     Spain  Female   41
# 2           3    15619304       Onio          502    France  Female   42
# 3           4    15701354       Boni          699    France  Female   39
# 4           5    15737888   Mitchell          850     Spain  Female   43
# 5           6    15574012        Chu          645     Spain    Male   44
# 6           7    15592531   Bartlett          822    France    Male   50
# 7           8    15656148     Obinna          376   Germany  Female   29
# 8           9    15792365         He          501    France    Male   44
# 9          10    15592389         H?          684    France    Male   27
# 10         11    15767821     Bearce          528    France    Male   31
# 11         12    15737173    Andrews          497     Spain    Male   24
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HDC0422037\Desktop\Churn_Modelling.csv")

print(df.head())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\HDC0422037\Desktop\Churn_Modelling.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        25 non-null     int64
#  1   CustomerId       25 non-null     int64
#  2   Surname          25 non-null     object
#  3   CreditScore      25 non-null     int64
#  4   Geography        25 non-null     object
#  5   Gender           25 non-null     object
#  6   Age              25 non-null     int64
#  7   Tenure           25 non-null     int64
#  8   Balance          25 non-null     float64
#  9   NumOfProducts    25 non-null     int64
#  10  HasCrCard        25 non-null     int64
#  11  IsActiveMember   25 non-null     int64
#  12  EstimatedSalary  25 non-null     float64
#  13  Exited           25 non-null     int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 2.9+ KB
# None

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\HDC0422037\Desktop\Churn_Modelling.csv")
print(df.describe())
# Out:
#        RowNumber    CustomerId  CreditScore        Age     Tenure  \
# count  25.000000  2.500000e+01    25.000000  25.000000  25.000000
# mean   13.000000  1.566413e+07   620.600000  37.640000   4.920000
# std     7.359801  6.934289e+04   118.825152   8.943713   2.722132
# min     1.000000  1.556898e+07   376.000000  24.000000   1.000000
# 25%     7.000000  1.560088e+07   528.000000  31.000000   3.000000
# 50%    13.000000  1.564731e+07   619.000000  39.000000   5.000000
# 75%    19.000000  1.572574e+07   684.000000  44.000000   7.000000
# max    25.000000  1.579236e+07   850.000000  58.000000  10.000000
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# count      25.000000      25.000000  25.000000       25.000000
# mean    50087.438400       1.800000   0.680000        0.520000
# std     64063.546275       0.707107   0.476095        0.509902
# min         0.000000       1.000000   0.000000        0.000000
# ...

# %%
import pandas as pd
df = pd.read_excel('C:\Users\HDC0422037\Desktop\Churn_Modelling.') 
print(df)
